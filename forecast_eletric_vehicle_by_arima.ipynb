# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from pmdarima import auto_arima

# %%
data = pd.read_csv("IEA Global EV Data 2024 new.csv", header = 0, delimiter = ",")
data
# Out:
#         region          category           parameter    mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit            value  \
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          percent               55
# 12650                       EV  2035          percent               31
# 12651  Publicly available fast  2035  charging points          9400000
# 12652  Publicly available slow  2035  charging points         15000000
# 12653                       EV  2035          percent                9
#
#                percentage
# 0               35000,00%
# 1      78999996185300,00%
# 2                 300,00%
# 3                 700,00%
# 4                6200,00%
# ...                   ...
# 12649            5500,00%
# 12650            3100,00%
# 12651       940000000,00%
# 12652      1500000000,00%
# 12653             900,00%
#
# [12654 rows x 9 columns]

# %%
data['value'] = pd.to_numeric(data['value'], errors='coerce')
data['percentage'] = pd.to_numeric(data['percentage'], errors='coerce')

# %%
data['value']
# Out:
# 0             350.0
# 1               NaN
# 2               3.0
# 3               7.0
# 4              62.0
#             ...
# 12649          55.0
# 12650          31.0
# 12651     9400000.0
# 12652    15000000.0
# 12653           9.0
# Name: value, Length: 12654, dtype: float64

# %%
data.isnull().sum()
# Out:
# region            0
# category          0
# parameter         0
# mode              0
# powertrain        0
# year              0
# unit              0
# value          3233
# percentage    12616
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data_group = data[["year", "value"]].groupby("year").sum().reset_index()
data_group
# Out:
#     year  value
# 0   2011   0.25
# 1   2014   0.50
# 2   2015   0.25
# 3   2016   3.50
# 4   2017   1.25
# 5   2018   0.75
# 6   2019   1.25
# 7   2020   1.75
# 8   2021   3.00
# 9   2022   1.50
# 10  2023   0.50
# 11  2030   0.75
# 12  2035   0.25

# %%
plt.plot(data_group["year"], data_group["value"])
plt.title("Visualize EV Sales follow each years")
plt.show()

# %%
data_corr = data_group.corr()
sns.heatmap(data_corr, annot = True)
plt.show()

# %%
train = data_group[data_group["year"] <= 2023]
test = data_group[data_group["year"] >= 2023]
train, test
# Out:
# (    year  value
#  0   2011   0.25
#  1   2014   0.50
#  2   2015   0.25
#  3   2016   3.50
#  4   2017   1.25
#  5   2018   0.75
#  6   2019   1.25
#  7   2020   1.75
#  8   2021   3.00
#  9   2022   1.50
#  10  2023   0.50,
#      year  value
#  10  2023   0.50
#  11  2030   0.75
#  12  2035   0.25)

# %%
adfuller(train["value"])
# Out:
# (-2.781185328699488,
#  0.061011975232483,
#  1,
#  9,
#  {'1%': -4.473135048010974,
#   '5%': -3.28988060356653,
#   '10%': -2.7723823456790124},
#  19.272979508238105)

# %%
train_diff_1 = train["value"].diff().dropna()
adfuller(train_diff_1)
# Out:
# (-3.322376869678028,
#  0.013907381219126266,
#  3,
#  6,
#  {'1%': -5.354256481481482,
#   '5%': -3.6462381481481483,
#   '10%': -2.901197777777778},
#  13.386246362519806)

# %%
plot_acf(train_diff_1)
plt.show()
plot_pacf(train_diff_1)
plt.show()

# %% [markdown]
# ## Check forecasting in

# %%
model_fit = ARIMA(train_diff_1, order=(5, 1, 5)).fit()
print(model_fit.summary())
forecast = model_fit.forecast(steps=len(test))

plt.plot(train["year"], train["value"], label="Train", color = "blue")
plt.plot(test["year"], test["value"], label="Test", color = "orange")
plt.plot(test["year"], forecast, label="Forecast", color = "red")
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   10
# Model:                 ARIMA(5, 1, 5)   Log Likelihood                 -11.777
# Date:                Sun, 24 Nov 2024   AIC                             45.554
# Time:                        12:49:18   BIC                             47.724
# Sample:                             0   HQIC                            40.873
#                                  - 10
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.7760   1751.584     -0.001      0.999   -3434.818    3431.266
# ar.L2         -1.9862   1832.545     -0.001      0.999   -3593.708    3589.735
# ar.L3         -2.0240   2092.075     -0.001      0.999   -4102.416    4098.368
# ar.L4         -1.6552   2273.190     -0.001      0.999   -4457.025    4453.715
# ar.L5         -0.6555   1380.658     -0.000      1.000   -2706.695    2705.384
# ma.L1         -0.4786    331.500     -0.001      0.999    -650.207     649.250
# ma.L2          0.9043    1.2e+04   7.55e-05      1.000   -2.35e+04    2.35e+04
# ma.L3          0.4748   8708.836   5.45e-05      1.000   -1.71e+04    1.71e+04
# ma.L4         -0.1653   5959.501  -2.77e-05      1.000   -1.17e+04    1.17e+04
# ma.L5          0.8362   3602.154      0.000      1.000   -7059.257    7060.929
# sigma2         0.0952    890.708      0.000      1.000   -1745.660    1745.850
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.32   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.25   Prob(JB):                         0.93
# Heteroskedasticity (H):               0.36   Skew:                             0.32
# Prob(H) (two-sided):                  0.43   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.09e+17. Standard errors may be unstable.

# %%
mean_squared_error(test["value"], forecast), mean_absolute_error(test["value"], forecast), mean_absolute_percentage_error(test["value"], forecast)
# MSE - MAE - MAPE
# Out:
# (0.11953850401929784, 0.33161931024197416, 0.7895807069961313)

# %% [markdown]
# ARIMA(3, 0, 2): (1.0244163286939914, 0.8274959591149648, 2.3628053091261276) <br/>
# ARIMA(1, 1, 2): (0.40697182114692954, 0.5722009145098567, 1.3275423228337007) <br/>
# ARIMA(1, 0, 1): (0.37306307270709005, 0.5418028490845743, 1.0486537413045798) <br/>
# ARIMA(0, 0, 0): (0.2672964185877666, 0.4750050019958736, 0.9389011159899132) <br/>
# ARIMA(2, 1, 1): (0.2531815420983404, 0.4832155621571108, 1.0562684452227664) <br/>
# ARIMA(1, 0, 0): (0.23168380763421972, 0.37097182184772115, 0.6798463135539675) <br/>
# ARIMA(1, 1, 1): (0.2240230576390695, 0.39240985221580865, 0.744984671530755) <br/>
# ARIMA(5, 1, 5): (0.11953850401929784, 0.33161931024197416, 0.7895807069961313) <br/>

# %%
auto_arima(train_diff_1, seasonal=False, stepwise=False)

# Auto arima model with seasonal=False and stepwise=False gives the best model as ARIMA(1, 0, 0) and ARIMA(0, 0, 0)
# Out:
# ARIMA(order=(3, 0, 2), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
residuals = model_fit.resid
fig, ax = plt.subplots(1, 2)
residuals.plot(title = "Residuals", ax = ax[0])
residuals.plot(title = "Destiny", kind = "kde", ax = ax[1])
plt.show()

# %%
model_fit = ARIMA(train_diff_1, order=(5, 2, 5)).fit()
print(model_fit.summary())

forecast_years = np.arange(2023, 2041)
forecast_steps = len(forecast_years)
forecast = model_fit.forecast(steps=forecast_steps)

plt.plot(train["year"], train["value"], label="Train", color = "blue")
plt.plot(test["year"], test["value"], label="Test", color = "orange")
plt.plot(forecast_years, forecast, label="Forecast", color = "red")
plt.title("Forecasting EV Sales by ARIMA Modeling")
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\HP\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   10
# Model:                 ARIMA(5, 2, 5)   Log Likelihood                 -12.311
# Date:                Sun, 24 Nov 2024   AIC                             46.621
# Time:                        12:49:20   BIC                             47.495
# Sample:                             0   HQIC                            40.728
#                                  - 10
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -2.1868      0.356     -6.142      0.000      -2.885      -1.489
# ar.L2         -2.6884      1.125     -2.390      0.017      -4.893      -0.484
# ar.L3         -2.6854      0.948     -2.833      0.005      -4.543      -0.828
# ar.L4         -2.1813      0.940     -2.321      0.020      -4.023      -0.340
# ar.L5         -0.9826      2.585     -0.380      0.704      -6.049       4.084
# ma.L1          0.1861    140.280      0.001      0.999    -274.757     275.129
# ma.L2          1.4702     43.931      0.033      0.973     -84.633      87.573
# ma.L3          0.7229     17.015      0.042      0.966     -32.626      34.072
# ma.L4          0.6697      8.391      0.080      0.936     -15.776      17.115
# ma.L5          0.6370     65.972      0.010      0.992    -128.666     129.940
# sigma2         0.0219      8.908      0.002      0.998     -17.438      17.482
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                 5.06
# Prob(Q):                              0.82   Prob(JB):                         0.08
# Heteroskedasticity (H):               0.39   Skew:                            -1.74
# Prob(H) (two-sided):                  0.46   Kurtosis:                         4.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.6e+18. Standard errors may be unstable.

# %%
mean_squared_error(forecast_years, forecast), mean_absolute_error(forecast_years, forecast), mean_absolute_percentage_error(forecast_years, forecast)
# Out:
# (4121745.6942141172, 2030.201794474657, 0.9993612754698193)

# %% [markdown]
# ARIMA(5, 1, 5): (4126892.6617287826, 2031.4681717732476, 0.9999841028224498) <br/>
# ARIMA(1, 1, 1): (4126808.942116284, 2031.4482102828506, 0.9999744832907275) <br/>
# ARIMA(5, 1, 1): (4126565.781916346, 2031.387602500944, 0.9999443919334582) <br/>
# ARIMA(3, 0, 2): (4126448.4943599724, 2031.358903730733, 0.9999303484982894) <br/>
# ARIMA(5, 2, 5): (4121745.6942141172, 2030.201794474657, 0.9993612754698193) <br/>

# %%
auto_arima(train_diff_1, seasonal=False, stepwise=False)
# Out:
# ARIMA(order=(3, 0, 2), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
residuals = model_fit.resid
fig, ax = plt.subplots(1, 2)
residuals.plot(title = "Residuals", ax = ax[0])
residuals.plot(title = "Destiny", kind = "kde", ax = ax[1])
plt.show()
